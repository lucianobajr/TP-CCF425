# %% [markdown]
# A importação das bibliotecas juntamente com o conjunto de dados utilizado foi realizado da seguinte maneira:

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.2)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 53.0 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 418 kB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.6.15)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# O conjunto de dados analisado foi encontrado através do repositório "COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University". A exibição dos dados que o Google utiliza também é baseada no mesmo dataset:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dentro do repositório acima, podemos ver que a obtenção dos dados relacionados ao Brasil é realizada por Wesley Cota da Universidade federal de viçosa. O repositório dele pode ser encontrado a partir de : https://github.com/wcota/covid19br

# %%
# !wget https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv
# !wget https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bcim/versao2016/geopackage/bcim_2016_21_11_2018.gpkg 
# !wget https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-16/esus-vepi.LeitoOcupacao_2021.csv
# !wget https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-18/esus-vepi.LeitoOcupacao_2022.csv 
# !wget https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-18/esus-vepi.LeitoOcupacao_2020.csv
# Out:
# --2022-07-26 10:56:09--  https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3810734 (3.6M) [text/plain]
# Saving to: ‘cases-brazil-states.csv’
#
# cases-brazil-states 100%[===================>]   3.63M  --.-KB/s    in 0.07s
#
# 2022-07-26 10:56:09 (53.1 MB/s) - ‘cases-brazil-states.csv’ saved [3810734/3810734]
#
# --2022-07-26 10:56:09--  https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bcim/versao2016/geopackage/bcim_2016_21_11_2018.gpkg
# Resolving geoftp.ibge.gov.br (geoftp.ibge.gov.br)... 191.233.136.86
# Connecting to geoftp.ibge.gov.br (geoftp.ibge.gov.br)|191.233.136.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 372666368 (355M)
# Saving to: ‘bcim_2016_21_11_2018.gpkg’
#
# bcim_2016_21_11_201 100%[===================>] 355.40M  19.2MB/s    in 19s
#
# 2022-07-26 10:56:29 (18.5 MB/s) - ‘bcim_2016_21_11_2018.gpkg’ saved [372666368/372666368]
#
# --2022-07-26 10:56:29--  https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-16/esus-vepi.LeitoOcupacao_2021.csv
# Resolving s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)... 52.95.165.43
# Connecting to s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)|52.95.165.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166963859 (159M) [binary/octet-stream]
# Saving to: ‘esus-vepi.LeitoOcupacao_2021.csv’
#
# esus-vepi.LeitoOcup 100%[===================>] 159.23M  21.8MB/s    in 8.3s
#
# 2022-07-26 10:56:38 (19.2 MB/s) - ‘esus-vepi.LeitoOcupacao_2021.csv’ saved [166963859/166963859]
#
# --2022-07-26 10:56:38--  https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-18/esus-vepi.LeitoOcupacao_2022.csv
# Resolving s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)... 16.12.0.4
# Connecting to s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)|16.12.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45556624 (43M) [binary/octet-stream]
# Saving to: ‘esus-vepi.LeitoOcupacao_2022.csv’
#
# esus-vepi.LeitoOcup 100%[===================>]  43.45M  14.6MB/s    in 3.0s
#
# 2022-07-26 10:56:42 (14.6 MB/s) - ‘esus-vepi.LeitoOcupacao_2022.csv’ saved [45556624/45556624]
#
# --2022-07-26 10:56:42--  https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/LEITOS/2022-06-18/esus-vepi.LeitoOcupacao_2020.csv
# Resolving s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)... 16.12.0.4
# Connecting to s3.sa-east-1.amazonaws.com (s3.sa-east-1.amazonaws.com)|16.12.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124779568 (119M) [binary/octet-stream]
# Saving to: ‘esus-vepi.LeitoOcupacao_2020.csv’
#
# esus-vepi.LeitoOcup 100%[===================>] 119.00M  20.2MB/s    in 6.7s
#
# 2022-07-26 10:56:49 (17.7 MB/s) - ‘esus-vepi.LeitoOcupacao_2020.csv’ saved [124779568/124779568]

# %% [markdown]
# Podemos ver todas as colunas da base de dados a seguir:
#
# ---

# %% [markdown]
# # Carregamento da base dos leitos

# %%
leitos_file1 = pd.read_csv('./esus-vepi.LeitoOcupacao_2020.csv')  
leitos_file2 = pd.read_csv('./esus-vepi.LeitoOcupacao_2021.csv') 
leitos_file3 = pd.read_csv('./esus-vepi.LeitoOcupacao_2022.csv')  
leitos_file = pd.concat([leitos_file1, leitos_file2, leitos_file3])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
to_drop = ['Unnamed: 0','cnes','_p_usuario','_created_at','_updated_at','origem','excluido','validado','estado','municipio']
leitos_file.drop(to_drop, inplace=True, axis=1) 
newDF = leitos_file.dropna() 
newDF.sort_values(['estadoNotificacao'])   

first_column = newDF.pop('estadoNotificacao')
second_column = newDF.pop('municipioNotificacao') 

  
newDF.insert(0, 'estadoNotificacao', first_column) 
newDF.insert(1, 'municipioNotificacao', first_column)

newDfTotal = newDF    

newDfTotal['totalOcupacaoSuspeita'] = newDfTotal['ocupacaoSuspeitoCli'] + newDfTotal['ocupacaoSuspeitoUti']
newDfTotal['totalOcupacaoConfirmados'] = newDfTotal['ocupacaoConfirmadoCli'] + newDfTotal['ocupacaoConfirmadoUti']
newDfTotal['totalOcupacaoCovid'] = newDfTotal['ocupacaoCovidCli'] + newDfTotal['ocupacaoCovidUti']
newDfTotal['totalOcupacaoHospitalar'] = newDfTotal['ocupacaoHospitalarUti'] + newDfTotal['ocupacaoHospitalarCli']


excluded_columns = ['ocupacaoSuspeitoCli', 'ocupacaoSuspeitoUti','ocupacaoConfirmadoCli','ocupacaoConfirmadoUti','ocupacaoCovidCli','ocupacaoCovidUti','ocupacaoHospitalarUti','ocupacaoHospitalarCli' ]

for i in excluded_columns: 
  newDfTotal.pop(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data = pd.read_csv('./cases-brazil-states.csv',nrows = 0, sep=',')
data
# Out:
# Empty DataFrame
# Columns: [epi_week, date, country, state, city, newDeaths, deaths, newCases, totalCases, deathsMS, totalCasesMS, deaths_per_100k_inhabitants, totalCases_per_100k_inhabitants, deaths_by_totalCases, recovered, suspects, tests, tests_per_100k_inhabitants, vaccinated, vaccinated_per_100_inhabitants, vaccinated_second, vaccinated_second_per_100_inhabitants, vaccinated_single, vaccinated_single_per_100_inhabitants, vaccinated_third, vaccinated_third_per_100_inhabitants]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.columns.values
# Out:
# array(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths',
#        'deaths', 'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'], dtype=object)

# %% [markdown]
# Podemos selecionar quais colunas queremos analisar:

# %%
cols = ['epi_week', 'date', 'country', 'state', 'city', 'newDeaths',
       'deaths', 'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
       'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
       'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
       'tests_per_100k_inhabitants', 'vaccinated',
       'vaccinated_per_100_inhabitants', 'vaccinated_second',
       'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
       'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
       'vaccinated_third_per_100_inhabitants']

# %%
cols = ['suspects','date','state','totalCases','vaccinated', 'vaccinated_per_100_inhabitants', 'vaccinated_second',
       'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
       'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
       'vaccinated_third_per_100_inhabitants','totalCases_per_100k_inhabitants','deaths','recovered']

# %%
data = pd.read_csv('./cases-brazil-states.csv', usecols = ['state'], sep=',') 
data
# Out:
#        state
# 0         SP
# 1      TOTAL
# 2         SP
# 3      TOTAL
# 4         SP
# ...      ...
# 24229     SC
# 24230     SE
# 24231     SP
# 24232     TO
# 24233  TOTAL
#
# [24234 rows x 1 columns]

# %%
data = pd.read_csv('./cases-brazil-states.csv',usecols = cols, sep=',')
data
# Out:
#              date  state  deaths  totalCases  totalCases_per_100k_inhabitants  \
# 0      2020-02-25     SP       0           1                          0.00218
# 1      2020-02-25  TOTAL       0           1                          0.00047
# 2      2020-02-26     SP       0           1                          0.00218
# 3      2020-02-26  TOTAL       0           1                          0.00047
# 4      2020-02-27     SP       0           1                          0.00218
# ...           ...    ...     ...         ...                              ...
# 24229  2022-07-25     SC   22186     1831364                      25560.61673
# 24230  2022-07-25     SE    6406      339776                      14781.24989
# 24231  2022-07-25     SP  172555     5883611                      12813.00708
# 24232  2022-07-25     TO    4182      337036                      21428.14455
# 24233  2022-07-25  TOTAL  677143    33621965                      15761.45562
#
#         recovered   suspects   vaccinated  vaccinated_per_100_inhabitants  \
# 0             NaN        NaN          NaN                             NaN
# 1             NaN        NaN          NaN                             NaN
# 2             NaN        NaN          NaN                             NaN
# 3             NaN        NaN          NaN                             NaN
# 4             NaN        NaN          NaN                             NaN
# ...           ...        ...          ...                             ...
# 24229   1607144.0   268966.0    6237943.0                        87.06389
# 24230    313577.0      445.0    1972991.0                        85.83088
# 24231   4850000.0   876238.0   42396507.0                        92.32880
# 24232    281464.0      359.0    1157010.0                        73.56062
# 24233  27381416.0  8866327.0  179861640.0                        84.31635
#
#        vaccinated_second  vaccinated_second_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 24229          5701626.0                               79.57843
# 24230          1808361.0                               78.66899
# 24231         39856763.0                               86.79788
# 24232           992190.0                               63.08166
# 24233        164821708.0                               77.26586
#
#        vaccinated_single  vaccinated_single_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 24229           277356.0                                3.87110
# 24230            42047.0                                1.82917
# 24231          1276302.0                                2.77946
# 24232            54944.0                                3.49324
# 24233          5346646.0                                2.50642
#
#        vaccinated_third  vaccinated_third_per_100_inhabitants
# 0                   NaN                                   NaN
# 1                   NaN                                   NaN
# 2                   NaN                                   NaN
# 3                   NaN                                   NaN
# 4                   NaN                                   NaN
# ...                 ...                                   ...
# 24229         3491346.0                              48.72923
# 24230         1211705.0                              52.71271
# 24231        33095195.0                              72.07291
# 24232          474217.0                              30.14987
# 24233       115289015.0                              54.04570
#
# [24234 rows x 15 columns]

# %% [markdown]
# É possível observar um ruído nos dados anteriores, há a ocorrência de diversas linhas com o Estado de "TOTAL", que representa  o total de casos por dia, podemos retirá-las para conseguir identificar apenas os estados que possuem casos registrados por dia

# %%
data = pd.read_csv('./cases-brazil-states.csv',usecols = cols, sep=',')
filtro = data['state'] != 'TOTAL'
dataFiltred = data[filtro]
dataFiltred
# Out:
#              date state  deaths  totalCases  totalCases_per_100k_inhabitants  \
# 0      2020-02-25    SP       0           1                          0.00218
# 2      2020-02-26    SP       0           1                          0.00218
# 4      2020-02-27    SP       0           1                          0.00218
# 6      2020-02-28    SP       0           2                          0.00436
# 8      2020-02-29    SP       0           2                          0.00436
# ...           ...   ...     ...         ...                              ...
# 24228  2022-07-25    RS   40373     2624124                      23064.68204
# 24229  2022-07-25    SC   22186     1831364                      25560.61673
# 24230  2022-07-25    SE    6406      339776                      14781.24989
# 24231  2022-07-25    SP  172555     5883611                      12813.00708
# 24232  2022-07-25    TO    4182      337036                      21428.14455
#
#        recovered  suspects  vaccinated  vaccinated_per_100_inhabitants  \
# 0            NaN       NaN         NaN                             NaN
# 2            NaN       NaN         NaN                             NaN
# 4            NaN       NaN         NaN                             NaN
# 6            NaN       NaN         NaN                             NaN
# 8            NaN       NaN         NaN                             NaN
# ...          ...       ...         ...                             ...
# 24228  2146461.0   10647.0   9722752.0                        85.45792
# 24229  1607144.0  268966.0   6237943.0                        87.06389
# 24230   313577.0     445.0   1972991.0                        85.83088
# 24231  4850000.0  876238.0  42396507.0                        92.32880
# 24232   281464.0     359.0   1157010.0                        73.56062
#
#        vaccinated_second  vaccinated_second_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 2                    NaN                                    NaN
# 4                    NaN                                    NaN
# 6                    NaN                                    NaN
# 8                    NaN                                    NaN
# ...                  ...                                    ...
# 24228          9203579.0                               80.89466
# 24229          5701626.0                               79.57843
# 24230          1808361.0                               78.66899
# 24231         39856763.0                               86.79788
# 24232           992190.0                               63.08166
#
#        vaccinated_single  vaccinated_single_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 2                    NaN                                    NaN
# 4                    NaN                                    NaN
# 6                    NaN                                    NaN
# 8                    NaN                                    NaN
# ...                  ...                                    ...
# 24228           330054.0                                2.90100
# 24229           277356.0                                3.87110
# 24230            42047.0                                1.82917
# 24231          1276302.0                                2.77946
# 24232            54944.0                                3.49324
#
#        vaccinated_third  vaccinated_third_per_100_inhabitants
# 0                   NaN                                   NaN
# 2                   NaN                                   NaN
# 4                   NaN                                   NaN
# 6                   NaN                                   NaN
# 8                   NaN                                   NaN
# ...                 ...                                   ...
# 24228         7045038.0                              61.92221
# 24229         3491346.0                              48.72923
# 24230         1211705.0                              52.71271
# 24231        33095195.0                              72.07291
# 24232          474217.0                              30.14987
#
# [23352 rows x 15 columns]

# %% [markdown]
# Conseguimos identificar o tipo de cada campo

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24234 entries, 0 to 24233
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   24234 non-null  object
#  1   state                                  24234 non-null  object
#  2   deaths                                 24234 non-null  int64
#  3   totalCases                             24234 non-null  int64
#  4   totalCases_per_100k_inhabitants        24234 non-null  float64
#  5   recovered                              23591 non-null  float64
#  6   suspects                               23640 non-null  float64
#  7   vaccinated                             15503 non-null  float64
#  8   vaccinated_per_100_inhabitants         15503 non-null  float64
#  9   vaccinated_second                      14823 non-null  float64
#  10  vaccinated_second_per_100_inhabitants  14823 non-null  float64
#  11  vaccinated_single                      10924 non-null  float64
#  12  vaccinated_single_per_100_inhabitants  10924 non-null  float64
#  13  vaccinated_third                       8664 non-null   float64
#  14  vaccinated_third_per_100_inhabitants   8664 non-null   float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 2.8+ MB

# %%
data.dtypes
# Out:
# date                                      object
# state                                     object
# deaths                                     int64
# totalCases                                 int64
# totalCases_per_100k_inhabitants          float64
# recovered                                float64
# suspects                                 float64
# vaccinated                               float64
# vaccinated_per_100_inhabitants           float64
# vaccinated_second                        float64
# vaccinated_second_per_100_inhabitants    float64
# vaccinated_single                        float64
# vaccinated_single_per_100_inhabitants    float64
# vaccinated_third                         float64
# vaccinated_third_per_100_inhabitants     float64
# dtype: object

# %% [markdown]
# Conseguimos identificar todos os valores não preenchidos nas colunas

# %%
data.isna().sum()
# Out:
# date                                         0
# state                                        0
# deaths                                       0
# totalCases                                   0
# totalCases_per_100k_inhabitants              0
# recovered                                  643
# suspects                                   594
# vaccinated                                8731
# vaccinated_per_100_inhabitants            8731
# vaccinated_second                         9411
# vaccinated_second_per_100_inhabitants     9411
# vaccinated_single                        13310
# vaccinated_single_per_100_inhabitants    13310
# vaccinated_third                         15570
# vaccinated_third_per_100_inhabitants     15570
# dtype: int64

# %%
data.describe()
# Out:
#               deaths    totalCases  totalCases_per_100k_inhabitants  \
# count   24234.000000  2.423400e+04                     24234.000000
# mean    27359.340596  1.084689e+06                      8376.706045
# std     85899.966706  3.471357e+06                      6502.506596
# min         0.000000  1.000000e+00                         0.000470
# 25%      2112.250000  1.081752e+05                      2841.184750
# 50%      7050.000000  3.044410e+05                      7545.992065
# 75%     17076.500000  7.044428e+05                     12857.742697
# max    677143.000000  3.362196e+07                     29751.757430
#
#           recovered      suspects    vaccinated  \
# count  2.359100e+04  2.364000e+04  1.550300e+04
# mean   9.955450e+05  3.903337e+05  8.392484e+06
# std    3.144648e+06  1.318382e+06  2.515316e+07
# min    1.000000e+00  1.000000e+00  2.000000e+00
# 25%    1.040625e+05  1.381000e+03  6.291230e+05
# 50%    2.814640e+05  1.143500e+04  2.437130e+06
# 75%    6.523010e+05  1.484510e+05  5.863186e+06
# max    2.738142e+07  8.866327e+06  1.798616e+08
#
#        vaccinated_per_100_inhabitants  vaccinated_second  \
# count                    15503.000000       1.482300e+04
# mean                        53.148667       6.630132e+06
# std                         29.959062       2.106509e+07
# min                          0.000010       1.000000e+00
# 25%                         22.082860       3.964295e+05
# 50%                         66.205950       1.760829e+06
# 75%                         77.989040       4.559371e+06
# max                         96.646030       1.648217e+08
#
#        vaccinated_second_per_100_inhabitants  vaccinated_single  \
# count                           14823.000000       1.092400e+04
# mean                               40.781028       3.451243e+05
# std                                28.163709       9.019994e+05
# min                                 0.000000       3.500000e+01
# 25%                                11.091740       5.050300e+04
# 50%                                45.795210       1.140330e+05
# 75%                                67.044645       2.617970e+05
# max                                86.797880       5.346646e+06
#
#        vaccinated_single_per_100_inhabitants  vaccinated_third  \
# count                           10924.000000      8.664000e+03
# mean                                2.285847      4.006504e+06
# std                                 1.412608      1.294473e+07
# min                                 0.000080      1.000000e+00
# 25%                                 1.690460      2.000160e+05
# 50%                                 1.962360      9.348030e+05
# 75%                                 2.503420      2.134781e+06
# max                                 9.298280      1.152890e+08
#
#        vaccinated_third_per_100_inhabitants
# count                           8664.000000
# mean                              22.071898
# std                               17.138510
# min                                0.000000
# 25%                                6.208947
# 50%                               20.149200
# 75%                               36.081430
# max                               72.072910

# %%
data['state'].value_counts()
# Out:
# SP       882
# TOTAL    882
# RJ       873
# BA       872
# ES       872
# DF       871
# AL       870
# MG       870
# RS       868
# GO       866
# PE       866
# PR       866
# RN       866
# SC       866
# AM       865
# MS       864
# SE       864
# CE       862
# AC       861
# PA       860
# PB       860
# TO       860
# PI       859
# AP       858
# MA       858
# MT       858
# RO       858
# RR       857
# Name: state, dtype: int64

# %%
data['year'] = pd.DatetimeIndex(data['date']).year

# %% [markdown]
# Podemos fitrar os numeros totais de casos ocorrido dentro de um período específico. Como por exemplo:

# %%
data_groupby = data.groupby('year')['totalCases'].sum()
data_groupby
# Out:
# year
# 2020     1784457032
# 2021    12414999752
# 2022    12086896958
# Name: totalCases, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.title("Número total de casos de Covid por ano")
data_groupby.plot(kind='bar', x='date', y='totalCases', color='purple', label = 'totalCases')

# %% [markdown]
# ## Relação entre vacinação e Estados

# %% [markdown]
# ### Eliminando ruídos do dataset

# %%
data_without_nan_values = data.dropna()
data_without_nan_values
# Out:
#              date  state  deaths  totalCases  totalCases_per_100k_inhabitants  \
# 15089  2021-09-02     MS    9403      369475                      13295.31707
# 15105  2021-09-02  TOTAL  582003    20834790                       9767.02635
# 15117  2021-09-03     MS    9411      369733                      13304.60103
# 15133  2021-09-03  TOTAL  582743    20858394                       9778.09153
# 15145  2021-09-04     MS    9418      369916                      13311.18617
# ...           ...    ...     ...         ...                              ...
# 24229  2022-07-25     SC   22186     1831364                      25560.61673
# 24230  2022-07-25     SE    6406      339776                      14781.24989
# 24231  2022-07-25     SP  172555     5883611                      12813.00708
# 24232  2022-07-25     TO    4182      337036                      21428.14455
# 24233  2022-07-25  TOTAL  677143    33621965                      15761.45562
#
#         recovered   suspects   vaccinated  vaccinated_per_100_inhabitants  \
# 15089    354985.0     1381.0    1836215.0                        66.07500
# 15105  19138604.0  7958935.0  133236457.0                        62.45918
# 15117    357475.0     1381.0    1839113.0                        66.17928
# 15133  19243454.0  7958935.0  133983801.0                        62.80953
# 15145    357475.0     1381.0    1844651.0                        66.37856
# ...           ...        ...          ...                             ...
# 24229   1607144.0   268966.0    6237943.0                        87.06389
# 24230    313577.0      445.0    1972991.0                        85.83088
# 24231   4850000.0   876238.0   42396507.0                        92.32880
# 24232    281464.0      359.0    1157010.0                        73.56062
# 24233  27381416.0  8866327.0  179861640.0                        84.31635
#
#        vaccinated_second  vaccinated_second_per_100_inhabitants  \
# 15089          1053662.0                               37.91534
# 15105         60244403.0                               28.24164
# 15117          1067906.0                               38.42790
# 15133         61424341.0                               28.79478
# 15145          1075969.0                               38.71804
# ...                  ...                                    ...
# 24229          5701626.0                               79.57843
# 24230          1808361.0                               78.66899
# 24231         39856763.0                               86.79788
# 24232           992190.0                               63.08166
# 24233        164821708.0                               77.26586
#
#        vaccinated_single  vaccinated_single_per_100_inhabitants  \
# 15089           234861.0                                8.45132
# 15105          4661248.0                                2.18512
# 15117           234861.0                                8.45132
# 15133          4669260.0                                2.18888
# 15145           234871.0                                8.45168
# ...                  ...                                    ...
# 24229           277356.0                                3.87110
# 24230            42047.0                                1.82917
# 24231          1276302.0                                2.77946
# 24232            54944.0                                3.49324
# 24233          5346646.0                                2.50642
#
#        vaccinated_third  vaccinated_third_per_100_inhabitants  year
# 15089             282.0                               0.01015  2021
# 15105             282.0                               0.00013  2021
# 15117             373.0                               0.01342  2021
# 15133             373.0                               0.00017  2021
# 15145             537.0                               0.01932  2021
# ...                 ...                                   ...   ...
# 24229         3491346.0                              48.72923  2022
# 24230         1211705.0                              52.71271  2022
# 24231        33095195.0                              72.07291  2022
# 24232          474217.0                              30.14987  2022
# 24233       115289015.0                              54.04570  2022
#
# [8664 rows x 16 columns]

# %%
vaccinated_per_state = data_without_nan_values.groupby('state')['vaccinated'].sum()

plt.figure(figsize =(11, 6))
plt.bar(vaccinated_per_state.index, vaccinated_per_state.values, color = 'orange')
plt.ylabel("Valores")
plt.xlabel("# Estados")
plt.title("Vacinação por Estados")
plt.xticks(rotation='vertical')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Analise de vacinação no estado de Minas Gerais

# %%
def total_vaccinated_per_year_by_state(state,year):
    data_with_month_column = data_without_nan_values.assign(month = pd.DatetimeIndex(data_without_nan_values['date']).month)
    total_vaccinated_per_month_in_mg = data_with_month_column[data_with_month_column['state'] == state]
    return total_vaccinated_per_month_in_mg[total_vaccinated_per_month_in_mg['year'] == year]


def mg_vaccinated(field,title):
    mg_2021_single = total_vaccinated_per_year_by_state("MG",2021).groupby('month')[field].sum().reset_index()
    plt.figure(figsize=(10,10))
    g=sns.barplot(data=mg_2021_single, y='month', x=field, orient='h')
    g.set_xscale('log')
    plt.title(title)
    plt.show()

mg_vaccinated('vaccinated',"Número total de vacinados com a primeira dose em MG por mês (2021)")

# %%
mg_vaccinated('vaccinated_single','Número total de vacinados com apenas primeira dose em MG por mês (2021)')

# %%
mg_vaccinated('vaccinated_second','Número total de vacinados com apenas duas dose em MG por mês (2021)')

# %%
mg_vaccinated('vaccinated_third','Número total de vacinados com três dose em MG por mês (2021)')

# %% [markdown]
# ## Mapa de calor referente a vacinação

# %%
display(data_without_nan_values.groupby('state')['vaccinated_per_100_inhabitants'].sum().sort_values())
# Out:
# state
# AP       19103.33216
# RR       19983.81297
# AC       20789.48551
# TO       21061.31480
# MA       21136.12592
# PA       21475.91618
# RO       21676.13839
# AM       21763.91979
# AL       22035.84518
# MT       22887.84782
# BA       23433.88525
# GO       23480.04406
# RN       23829.72098
# RJ       23851.80032
# SE       24174.17143
# DF       24460.16213
# CE       24554.01673
# MS       24799.45871
# RS       25061.67290
# PE       25112.09828
# MG       25166.34059
# PB       25210.83086
# TOTAL    25465.30413
# ES       25617.65376
# SC       25661.04186
# PR       25747.41247
# PI       25953.83796
# SP       28097.74296
# Name: vaccinated_per_100_inhabitants, dtype: float64

# %% [markdown]
# ### Vacinados por 100k de Habitantes

# %%
INFOS_UFS = gpd.read_file('./bcim_2016_21_11_2018.gpkg', layer = 'lim_unidade_federacao_a')
INFOS_UFS.rename({'sigla':'state'}, axis = 1, inplace = True)

df_br = INFOS_UFS.merge(data_without_nan_values, on = 'state', how = 'left')

df_br.plot(column = 'vaccinated_per_100_inhabitants',
    cmap  = 'Reds',
    figsize = (16,10),
    legend = True,
    edgecolor = 'black',
    
    )

# %% [markdown]
# ### Total de casos de Covid por 100k de Habitantes

# %%
df_br.plot(column = 'totalCases_per_100k_inhabitants',
    cmap  = 'Reds',
    figsize = (16,10),
    legend = True,
    edgecolor = 'black',
    )

# %% [markdown]
# # Regressão

# %% [markdown]
# Análisando a tabela de correlações podemos manter ou retirar algumas colunas para realizar a regressão:

# %%
cols_interesse = [
        'totalCases_per_100k_inhabitants', 'recovered', 'suspects',
       'tests_per_100k_inhabitants',
       'vaccinated_per_100_inhabitants', 
       'vaccinated_second_per_100_inhabitants', 
       'vaccinated_single_per_100_inhabitants', 
       'vaccinated_third_per_100_inhabitants']
target = 'state'

# %%
cols_interesse_all = cols_interesse.copy()
#cols_interesse_all.append(target)  
data = pd.read_csv('./cases-brazil-states.csv')

df = data.dropna() 
df[cols_interesse_all]
# Out:
#        totalCases_per_100k_inhabitants   recovered   suspects  \
# 15089                      13295.31707    354985.0     1381.0
# 15105                       9767.02635  19138604.0  7958935.0
# 15117                      13304.60103    357475.0     1381.0
# 15133                       9778.09153  19243454.0  7958935.0
# 15145                      13311.18617    357475.0     1381.0
# ...                                ...         ...        ...
# 24229                      25560.61673   1607144.0   268966.0
# 24230                      14781.24989    313577.0      445.0
# 24231                      12813.00708   4850000.0   876238.0
# 24232                      21428.14455    281464.0      359.0
# 24233                      15761.45562  27381416.0  8866327.0
#
#        tests_per_100k_inhabitants  vaccinated_per_100_inhabitants  \
# 15089                 37019.54598                        66.07500
# 15105                 26706.17267                        62.45918
# 15117                 37349.52245                        66.17928
# 15133                 26765.35296                        62.80953
# 15145                 37349.52245                        66.37856
# ...                           ...                             ...
# 24229                 35847.42493                        87.06389
# 24230                 26283.72782                        85.83088
# 24231                 42469.91918                        92.32880
# 24232                 57473.10960                        73.56062
# 24233                 33247.70297                        84.31635
#
#        vaccinated_second_per_100_inhabitants  \
# 15089                               37.91534
# 15105                               28.24164
# 15117                               38.42790
# 15133                               28.79478
# 15145                               38.71804
# ...                                      ...
# 24229                               79.57843
# 24230                               78.66899
# 24231                               86.79788
# 24232                               63.08166
# 24233                               77.26586
#
#        vaccinated_single_per_100_inhabitants  \
# 15089                                8.45132
# 15105                                2.18512
# 15117                                8.45132
# 15133                                2.18888
# 15145                                8.45168
# ...                                      ...
# 24229                                3.87110
# 24230                                1.82917
# 24231                                2.77946
# 24232                                3.49324
# 24233                                2.50642
#
#        vaccinated_third_per_100_inhabitants
# 15089                               0.01015
# 15105                               0.00013
# 15117                               0.01342
# 15133                               0.00017
# 15145                               0.01932
# ...                                     ...
# 24229                              48.72923
# 24230                              52.71271
# 24231                              72.07291
# 24232                              30.14987
# 24233                              54.04570
#
# [8664 rows x 8 columns]

# %% [markdown]
# ## Correlações
# A correlação diz se dois atributos no dataset possuem alguma relação.

# %%
correlations = df.corr()
print(correlations)
# Out:
#                                        epi_week  newDeaths    deaths  \
# epi_week                               1.000000  -0.045049 -0.004645
# newDeaths                             -0.045049   1.000000  0.716207
# deaths                                -0.004645   0.716207  1.000000
# newCases                               0.089933   0.744855  0.594109
# totalCases                             0.039462   0.689381  0.987722
# deathsMS                              -0.004638   0.716173  1.000000
# totalCasesMS                           0.039467   0.689256  0.987713
# deaths_per_100k_inhabitants            0.130540   0.056532  0.092174
# totalCases_per_100k_inhabitants        0.385403  -0.099652 -0.113154
# deaths_by_totalCases                  -0.369598   0.169240  0.207788
# recovered                              0.026256   0.687038  0.991219
# suspects                              -0.003072   0.641052  0.883580
# tests                                  0.000391   0.707971  0.994426
# tests_per_100k_inhabitants             0.105940  -0.010317 -0.013513
# vaccinated                             0.005331   0.707572  0.998215
# vaccinated_per_100_inhabitants         0.595261   0.062035  0.143508
# vaccinated_second                      0.045118   0.667090  0.984804
# vaccinated_second_per_100_inhabitants  0.720719   0.023802  0.120014
# vaccinated_single                     -0.007438   0.715493  0.998166
# vaccinated_single_per_100_inhabitants  0.049535   0.001017  0.003610
# vaccinated_third                       0.193596   0.471926  0.815747
# vaccinated_third_per_100_inhabitants   0.809956   0.011547  0.107904
#
#                                        newCases  totalCases  deathsMS  \
# epi_week                               0.089933    0.039462 -0.004638
# newDeaths                              0.744855    0.689381  0.716173
# deaths                                 0.594109    0.987722  1.000000
# newCases                               1.000000    0.605179  0.594084
# totalCases                             0.605179    1.000000  0.987725
# deathsMS                               0.594084    0.987725  1.000000
# totalCasesMS                           0.605006    1.000000  0.987716
# deaths_per_100k_inhabitants            0.061157    0.081590  0.092178
# totalCases_per_100k_inhabitants       -0.024136   -0.061737 -0.113151
# deaths_by_totalCases                   0.062531    0.123951  0.207788
# recovered                              0.589147    0.998675  0.991222
# suspects                               0.557115    0.891156  0.883579
# tests                                  0.593889    0.985972  0.994426
# tests_per_100k_inhabitants             0.009449    0.005957 -0.013510
# vaccinated                             0.598506    0.991380  0.998216
# vaccinated_per_100_inhabitants         0.099672    0.160979  0.143517
# vaccinated_second                      0.613271    0.989431  0.984808
# vaccinated_second_per_100_inhabitants  0.114485    0.145232  0.120023
# vaccinated_single                      0.595147    0.988179  0.998165
# vaccinated_single_per_100_inhabitants  0.009020    0.011599  0.003607
# vaccinated_third                       0.537952    0.874496  0.815764
# vaccinated_third_per_100_inhabitants   0.093616    0.147176  0.107916
#
#                                        totalCasesMS  \
# epi_week                                   0.039467
# newDeaths                                  0.689256
# deaths                                     0.987713
# newCases                                   0.605006
# totalCases                                 1.000000
# deathsMS                                   0.987716
# totalCasesMS                               1.000000
# deaths_per_100k_inhabitants                0.081598
# totalCases_per_100k_inhabitants           -0.061729
# deaths_by_totalCases                       0.123950
# recovered                                  0.998677
# suspects                                   0.891145
# tests                                      0.985964
# tests_per_100k_inhabitants                 0.005962
# vaccinated                                 0.991372
# vaccinated_per_100_inhabitants             0.161004
# vaccinated_second                          0.989428
# vaccinated_second_per_100_inhabitants      0.145251
# vaccinated_single                          0.988170
# vaccinated_single_per_100_inhabitants      0.011589
# vaccinated_third                           0.874534
# vaccinated_third_per_100_inhabitants       0.147209
#
#                                        deaths_per_100k_inhabitants  \
# epi_week                                                  0.130540
# newDeaths                                                 0.056532
# deaths                                                    0.092174
# newCases                                                  0.061157
# totalCases                                                0.081590
# deathsMS                                                  0.092178
# totalCasesMS                                              0.081598
# deaths_per_100k_inhabitants                               1.000000
# totalCases_per_100k_inhabitants                           0.625250
# deaths_by_totalCases                                      0.095207
# recovered                                                 0.079609
# suspects                                                  0.025200
# tests                                                     0.075306
# tests_per_100k_inhabitants                                0.396245
# vaccinated                                                0.055379
# vaccinated_per_100_inhabitants                            0.229397
# vaccinated_second                                         0.064794
# vaccinated_second_per_100_inhabitants                     0.225042
# vaccinated_single                                         0.074652
# vaccinated_single_per_100_inhabitants                     0.357537
# vaccinated_third                                          0.095030
# vaccinated_third_per_100_inhabitants                      0.225587
#
#                                        totalCases_per_100k_inhabitants  \
# epi_week                                                      0.385403
# newDeaths                                                    -0.099652
# deaths                                                       -0.113154
# newCases                                                     -0.024136
# totalCases                                                   -0.061737
# deathsMS                                                     -0.113151
# totalCasesMS                                                 -0.061729
# deaths_per_100k_inhabitants                                   0.625250
# totalCases_per_100k_inhabitants                               1.000000
# deaths_by_totalCases                                         -0.665456
# recovered                                                    -0.068324
# suspects                                                     -0.068062
# tests                                                        -0.094152
# tests_per_100k_inhabitants                                    0.618963
# vaccinated                                                   -0.124661
# vaccinated_per_100_inhabitants                                0.183919
# vaccinated_second                                            -0.108795
# vaccinated_second_per_100_inhabitants                         0.234303
# vaccinated_single                                            -0.106434
# vaccinated_single_per_100_inhabitants                         0.275954
# vaccinated_third                                             -0.022883
# vaccinated_third_per_100_inhabitants                          0.334269
#
#                                        deaths_by_totalCases  ...     tests  \
# epi_week                                          -0.369598  ...  0.000391
# newDeaths                                          0.169240  ...  0.707971
# deaths                                             0.207788  ...  0.994426
# newCases                                           0.062531  ...  0.593889
# totalCases                                         0.123951  ...  0.985972
# deathsMS                                           0.207788  ...  0.994426
# totalCasesMS                                       0.123950  ...  0.985964
# deaths_per_100k_inhabitants                        0.095207  ...  0.075306
# totalCases_per_100k_inhabitants                   -0.665456  ... -0.094152
# deaths_by_totalCases                               1.000000  ...  0.163132
# recovered                                          0.131603  ...  0.989288
# suspects                                           0.071366  ...  0.881717
# tests                                              0.163132  ...  1.000000
# tests_per_100k_inhabitants                        -0.406409  ...  0.046501
# vaccinated                                         0.186206  ...  0.995374
# vaccinated_per_100_inhabitants                    -0.066662  ...  0.159944
# vaccinated_second                                  0.170270  ...  0.985964
# vaccinated_second_per_100_inhabitants             -0.131533  ...  0.137218
# vaccinated_single                                  0.180661  ...  0.995458
# vaccinated_single_per_100_inhabitants             -0.060830  ...  0.014490
# vaccinated_third                                   0.073402  ...  0.822795
# vaccinated_third_per_100_inhabitants              -0.246575  ...  0.121957
#
#                                        tests_per_100k_inhabitants  vaccinated  \
# epi_week                                                 0.105940    0.005331
# newDeaths                                               -0.010317    0.707572
# deaths                                                  -0.013513    0.998215
# newCases                                                 0.009449    0.598506
# totalCases                                               0.005957    0.991380
# deathsMS                                                -0.013510    0.998216
# totalCasesMS                                             0.005962    0.991372
# deaths_per_100k_inhabitants                              0.396245    0.055379
# totalCases_per_100k_inhabitants                          0.618963   -0.124661
# deaths_by_totalCases                                    -0.406409    0.186206
# recovered                                                0.003449    0.994167
# suspects                                                -0.010482    0.889881
# tests                                                    0.046501    0.995374
# tests_per_100k_inhabitants                               1.000000   -0.020417
# vaccinated                                              -0.020417    1.000000
# vaccinated_per_100_inhabitants                           0.053328    0.146939
# vaccinated_second                                       -0.010671    0.990763
# vaccinated_second_per_100_inhabitants                    0.079541    0.126723
# vaccinated_single                                       -0.000216    0.997879
# vaccinated_single_per_100_inhabitants                    0.301301   -0.004668
# vaccinated_third                                         0.024011    0.830885
# vaccinated_third_per_100_inhabitants                     0.141441    0.113714
#
#                                        vaccinated_per_100_inhabitants  \
# epi_week                                                     0.595261
# newDeaths                                                    0.062035
# deaths                                                       0.143508
# newCases                                                     0.099672
# totalCases                                                   0.160979
# deathsMS                                                     0.143517
# totalCasesMS                                                 0.161004
# deaths_per_100k_inhabitants                                  0.229397
# totalCases_per_100k_inhabitants                              0.183919
# deaths_by_totalCases                                        -0.066662
# recovered                                                    0.153343
# suspects                                                     0.115296
# tests                                                        0.159944
# tests_per_100k_inhabitants                                   0.053328
# vaccinated                                                   0.146939
# vaccinated_per_100_inhabitants                               1.000000
# vaccinated_second                                            0.178327
# vaccinated_second_per_100_inhabitants                        0.932307
# vaccinated_single                                            0.141006
# vaccinated_single_per_100_inhabitants                        0.149120
# vaccinated_third                                             0.261462
# vaccinated_third_per_100_inhabitants                         0.821831
#
#                                        vaccinated_second  \
# epi_week                                        0.045118
# newDeaths                                       0.667090
# deaths                                          0.984804
# newCases                                        0.613271
# totalCases                                      0.989431
# deathsMS                                        0.984808
# totalCasesMS                                    0.989428
# deaths_per_100k_inhabitants                     0.064794
# totalCases_per_100k_inhabitants                -0.108795
# deaths_by_totalCases                            0.170270
# recovered                                       0.988863
# suspects                                        0.876778
# tests                                           0.985964
# tests_per_100k_inhabitants                     -0.010671
# vaccinated                                      0.990763
# vaccinated_per_100_inhabitants                  0.178327
# vaccinated_second                               1.000000
# vaccinated_second_per_100_inhabitants           0.170511
# vaccinated_single                               0.983659
# vaccinated_single_per_100_inhabitants          -0.000911
# vaccinated_third                                0.882940
# vaccinated_third_per_100_inhabitants            0.154891
#
#                                        vaccinated_second_per_100_inhabitants  \
# epi_week                                                            0.720719
# newDeaths                                                           0.023802
# deaths                                                              0.120014
# newCases                                                            0.114485
# totalCases                                                          0.145232
# deathsMS                                                            0.120023
# totalCasesMS                                                        0.145251
# deaths_per_100k_inhabitants                                         0.225042
# totalCases_per_100k_inhabitants                                     0.234303
# deaths_by_totalCases                                               -0.131533
# recovered                                                           0.135970
# suspects                                                            0.099929
# tests                                                               0.137218
# tests_per_100k_inhabitants                                          0.079541
# vaccinated                                                          0.126723
# vaccinated_per_100_inhabitants                                      0.932307
# vaccinated_second                                                   0.170511
# vaccinated_second_per_100_inhabitants                               1.000000
# vaccinated_single                                                   0.117799
# vaccinated_single_per_100_inhabitants                               0.151034
# vaccinated_third                                                    0.268984
# vaccinated_third_per_100_inhabitants                                0.859123
#
#                                        vaccinated_single  \
# epi_week                                       -0.007438
# newDeaths                                       0.715493
# deaths                                          0.998166
# newCases                                        0.595147
# totalCases                                      0.988179
# deathsMS                                        0.998165
# totalCasesMS                                    0.988170
# deaths_per_100k_inhabitants                     0.074652
# totalCases_per_100k_inhabitants                -0.106434
# deaths_by_totalCases                            0.180661
# recovered                                       0.991877
# suspects                                        0.889581
# tests                                           0.995458
# tests_per_100k_inhabitants                     -0.000216
# vaccinated                                      0.997879
# vaccinated_per_100_inhabitants                  0.141006
# vaccinated_second                               0.983659
# vaccinated_second_per_100_inhabitants           0.117799
# vaccinated_single                               1.000000
# vaccinated_single_per_100_inhabitants           0.040716
# vaccinated_third                                0.811599
# vaccinated_third_per_100_inhabitants            0.106022
#
#                                        vaccinated_single_per_100_inhabitants  \
# epi_week                                                            0.049535
# newDeaths                                                           0.001017
# deaths                                                              0.003610
# newCases                                                            0.009020
# totalCases                                                          0.011599
# deathsMS                                                            0.003607
# totalCasesMS                                                        0.011589
# deaths_per_100k_inhabitants                                         0.357537
# totalCases_per_100k_inhabitants                                     0.275954
# deaths_by_totalCases                                               -0.060830
# recovered                                                           0.011787
# suspects                                                           -0.008245
# tests                                                               0.014490
# tests_per_100k_inhabitants                                          0.301301
# vaccinated                                                         -0.004668
# vaccinated_per_100_inhabitants                                      0.149120
# vaccinated_second                                                  -0.000911
# vaccinated_second_per_100_inhabitants                               0.151034
# vaccinated_single                                                   0.040716
# vaccinated_single_per_100_inhabitants                               1.000000
# vaccinated_third                                                    0.015178
# vaccinated_third_per_100_inhabitants                                0.180013
#
#                                        vaccinated_third  \
# epi_week                                       0.193596
# newDeaths                                      0.471926
# deaths                                         0.815747
# newCases                                       0.537952
# totalCases                                     0.874496
# deathsMS                                       0.815764
# totalCasesMS                                   0.874534
# deaths_per_100k_inhabitants                    0.095030
# totalCases_per_100k_inhabitants               -0.022883
# deaths_by_totalCases                           0.073402
# recovered                                      0.857092
# suspects                                       0.721583
# tests                                          0.822795
# tests_per_100k_inhabitants                     0.024011
# vaccinated                                     0.830885
# vaccinated_per_100_inhabitants                 0.261462
# vaccinated_second                              0.882940
# vaccinated_second_per_100_inhabitants          0.268984
# vaccinated_single                              0.811599
# vaccinated_single_per_100_inhabitants          0.015178
# vaccinated_third                               1.000000
# vaccinated_third_per_100_inhabitants           0.320616
#
#                                        vaccinated_third_per_100_inhabitants
# epi_week                                                           0.809956
# newDeaths                                                          0.011547
# deaths                                                             0.107904
# newCases                                                           0.093616
# totalCases                                                         0.147176
# deathsMS                                                           0.107916
# totalCasesMS                                                       0.147209
# deaths_per_100k_inhabitants                                        0.225587
# totalCases_per_100k_inhabitants                                    0.334269
# deaths_by_totalCases                                              -0.246575
# recovered                                                          0.132892
# suspects                                                           0.094279
# tests                                                              0.121957
# tests_per_100k_inhabitants                                         0.141441
# vaccinated                                                         0.113714
# vaccinated_per_100_inhabitants                                     0.821831
# vaccinated_second                                                  0.154891
# vaccinated_second_per_100_inhabitants                              0.859123
# vaccinated_single                                                  0.106022
# vaccinated_single_per_100_inhabitants                              0.180013
# vaccinated_third                                                   0.320616
# vaccinated_third_per_100_inhabitants                               1.000000
#
# [22 rows x 22 columns]

# %%
df.dtypes
# Out:
# epi_week                                   int64
# date                                      object
# country                                   object
# state                                     object
# city                                      object
# newDeaths                                  int64
# deaths                                     int64
# newCases                                   int64
# totalCases                                 int64
# deathsMS                                   int64
# totalCasesMS                               int64
# deaths_per_100k_inhabitants              float64
# totalCases_per_100k_inhabitants          float64
# deaths_by_totalCases                     float64
# recovered                                float64
# suspects                                 float64
# tests                                    float64
# tests_per_100k_inhabitants               float64
# vaccinated                               float64
# vaccinated_per_100_inhabitants           float64
# vaccinated_second                        float64
# vaccinated_second_per_100_inhabitants    float64
# vaccinated_single                        float64
# vaccinated_single_per_100_inhabitants    float64
# vaccinated_third                         float64
# vaccinated_third_per_100_inhabitants     float64
# dtype: object

# %%
df['state'] = df["state"].astype('category')
df['state'] = df['state'].cat.codes 
df['city'] = df["city"].astype('category')
df['city'] = df['city'].cat.codes 
df['country'] = df["country"].astype('category')
df['country'] = df['country'].cat.codes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = pd.get_dummies(df, columns=["state"])

# %%
df = df.drop(['date'], axis=1)

# %%
df.dtypes
# Out:
# epi_week                                   int64
# country                                     int8
# city                                        int8
# newDeaths                                  int64
# deaths                                     int64
# newCases                                   int64
# totalCases                                 int64
# deathsMS                                   int64
# totalCasesMS                               int64
# deaths_per_100k_inhabitants              float64
# totalCases_per_100k_inhabitants          float64
# deaths_by_totalCases                     float64
# recovered                                float64
# suspects                                 float64
# tests                                    float64
# tests_per_100k_inhabitants               float64
# vaccinated                               float64
# vaccinated_per_100_inhabitants           float64
# vaccinated_second                        float64
# vaccinated_second_per_100_inhabitants    float64
# vaccinated_single                        float64
# vaccinated_single_per_100_inhabitants    float64
# vaccinated_third                         float64
# vaccinated_third_per_100_inhabitants     float64
# state_0                                    uint8
# state_1                                    uint8
# state_2                                    uint8
# state_3                                    uint8
# state_4                                    uint8
# state_5                                    uint8
# state_6                                    uint8
# state_7                                    uint8
# state_8                                    uint8
# state_9                                    uint8
# state_10                                   uint8
# state_11                                   uint8
# state_12                                   uint8
# state_13                                   uint8
# state_14                                   uint8
# state_15                                   uint8
# state_16                                   uint8
# state_17                                   uint8
# state_18                                   uint8
# state_19                                   uint8
# state_20                                   uint8
# state_21                                   uint8
# state_22                                   uint8
# state_23                                   uint8
# state_24                                   uint8
# state_25                                   uint8
# state_26                                   uint8
# state_27                                   uint8
# dtype: object

# %% [markdown]
# # Utilização de coeficiente de person para verificar relação entre variáveis

# %%
Var_Corr = df[cols_interesse_all].corr()
matrix = np.triu(df[cols_interesse_all].corr())

plt.figure(figsize = (20,7))
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns,\
            annot=True,center= 0, cmap= 'coolwarm',mask=matrix)

# %%
from sklearn.linear_model import LinearRegression

def regressao_linear(X,Y,cols):

  if len(cols) == 1:
    X = X.values.reshape(-1,1)

  lm = LinearRegression()
  lm.fit(X,Y)
  print('Coeficiente estimado: ', lm.coef_)    
  print('R2 (score): ', lm.score(X,Y))
  print("Intercept %.3f " % lm.intercept_)

  coeff_df = pd.DataFrame(lm.coef_, cols, columns=['Coefficient'])
  print(coeff_df)

# %%
import statsmodels.api as sm  
Y = df['suspects']
cols_interesse_novo = ['recovered'] 

X = df[cols_interesse_novo] 
results = sm.OLS(Y,X.astype(float)).fit()
print(results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               suspects   R-squared (uncentered):                   0.822
# Model:                            OLS   Adj. R-squared (uncentered):              0.822
# Method:                 Least Squares   F-statistic:                          4.005e+04
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):                        0.00
# Time:                        05:06:02   Log-Likelihood:                     -1.3011e+05
# No. Observations:                8664   AIC:                                  2.602e+05
# Df Residuals:                    8663   BIC:                                  2.602e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# recovered      0.3567      0.002    200.114      0.000       0.353       0.360
# ==============================================================================
# Omnibus:                     6964.091   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120393.749
# Skew:                           3.944   Prob(JB):                         0.00
# Kurtosis:                      19.471   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Perguntas

# %% [markdown]
# ## 1) Qual região do país apresentou maior apatia ao programa de vacinação contra a COVID-19?

# %%
sudeste = ['ES','MG','RJ','SP']  
nordeste = ['AL','BA','CE','MA','PA','PB','PE','PI','RN','SE']
centro_oeste = ['MT','MS','DF','GO']
norte = ['AM','AC','TO','AP','RO','RR']
sul = ['PR','RS','SC','PR']  


def sum_vac_by_region(region):
  
  sum = 0 
  for state in region:
    sum += df[df['state'] == state]['Total_vac_per_100'].sum()
    
  return sum


def list_of_differentes(regions):
  values = []
  for region in regions:
    values.append(sum_vac_by_region(region))

  return values  
 
cols = ['date', 'state',  'vaccinated_per_100_inhabitants',
       'vaccinated_second_per_100_inhabitants', 
       'vaccinated_single_per_100_inhabitants', 
       'vaccinated_third_per_100_inhabitants']  

data_1 = pd.read_csv('./cases-brazil-states.csv',usecols = cols, sep=',') 
df = data_1.dropna()  
df['Total_vac_per_100'] = df['vaccinated_per_100_inhabitants'] + df['vaccinated_second_per_100_inhabitants'] + df['vaccinated_single_per_100_inhabitants'] + df['vaccinated_third_per_100_inhabitants']

total_vac = df.groupby('state')['Total_vac_per_100'].sum()

values = list_of_differentes([norte,nordeste,centro_oeste,sudeste,sul])
regions = ['Norte','Nordeste','Centro Oeste','Sudeste','Sul'] 


print(values)

plt.figure(figsize =(11, 6))
plt.bar(regions, values, color = 'green')
plt.ylabel("Vacinação")
plt.xlabel("# Regiões")
plt.title("Vacinação por Região")
plt.xticks(rotation='vertical')
plt.yscale('log')
plt.show()
# Out:
# [246100.76424, 506147.91456, 207942.08662, 229154.86552, 226248.48038000002]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Analisando o gráfic juntamente com as informações coletadas nota-se que a região centro-oeste foi a que mais apresentou apatia à vacinação nos estados que a compõem.

# %% [markdown]
# ## 2) Qual região brasileira apresentou maior redução de mortes causadas por COVID-19 após o início das vacinações (Março/Abril 2021)?

# %%
# Regiões

norte = ['AM', 'PA', 'RR', 'AP', 'RO', 'AC' , 'TO']
nordeste =  ['PI', 'MA', 'PE', 'RN', 'PB', 'CE', 'BA', 'AL','SE']
centro_oeste =  ['MT', 'MS','GO']
sudeste =  ['SP', 'RJ', 'ES', 'MG']
sul =  ['RS', 'PR', 'SC']

# %%
start_vaccination = '2021-01-17'

data = data[data != 'TOTAL']

def difference_before_and_after_vaccinating(region):
  sum_before = 0
  sum_after = 0

  df_before = data[data['date']<start_vaccination]
  df_after = data[data['date']>=start_vaccination]

  for state in region:
    sum_before += df_before[df_before['state'] == state]['deaths'].sum()
    sum_after += df_after[df_after['state'] == state]['deaths'].sum()
  
  return sum_after - sum_before


def list_of_differentes(regions):
  values = []
  for region in regions:
    values.append(difference_before_and_after_vaccinating(region))

  return values  

values = list_of_differentes([norte,nordeste,centro_oeste,sudeste,sul])
regions = ['Norte','Nordeste','Centro Oeste','Sudeste','Sul']

# %%
plt.figure(figsize =(11, 6))
plt.bar(regions, values, color = 'orange')
plt.ylabel("Valores")
plt.xlabel("# Estados")
plt.title("Maior redução de mortes após o início da vacinação")
plt.yscale('log')
plt.show()

# %% [markdown]
# ## 3) Qual região brasileira é mais afetada pela COVID-19?

# %%
# Para se ter uma métrica justa utilizaremos o total de casos por 100l de habitantes
# totalCases_per_100k_inhabitants

def total_cases_by_region(region):
  sum = 0
  for state in region:
    sum +=  data_without_nan_values[data_without_nan_values['state'] == state]['totalCases_per_100k_inhabitants'].sum()

  return sum


def list_of_values(regions):
  values = []
  for region in regions:
    values.append(total_cases_by_region(region))

  return values

values = list_of_values([norte,nordeste,centro_oeste,sudeste,sul])
regions = ['Norte','Nordeste','Centro Oeste','Sudeste','Sul']

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=values, y =regions , orient="h", palette="Set2")
plt.title('Total de casos de COVID-19 por Regiões brasileiras (por 100k de habitantes)',
          position=(0.5, 1.02),
          fontdict={'family': 'sans serif',
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 18})
plt.xlabel('Total', 
           fontdict={'family': 'sans serif',
                     'color' : 'black',
                     'weight': 'bold',
                     'size': 12})
plt.ylabel('Regiões', 
           fontdict={'family': 'sans serif',
                     'color' : 'black',
                     'weight': 'bold',
                     'size': 12})
plt.show()

# %% [markdown]
# Nota-se a partir do gráfico anterior que a região Norte é a mais afetada

# %% [markdown]
# ## 4) Qual o avanço da COVID-19 no interior do Brasil?

# %%
## Roraima, Amapá e Acre

data_without_nan_values['date'].min()

def plot_graph(dataframe,color,title):
  plt.figure(figsize = (18,9))
  plt.ticklabel_format(style = 'plain')
  plt.xticks([])
  plt.title(title,
            position=(0.5, 1.02),
            fontdict={'family': 'sans serif',
                      'color' : 'black',
                      'weight': 'bold',
                      'size': 18})
  plt.xlabel('Data mm/dd/aa',
              fontdict={'family': 'sans serif',
                        'color' : 'black',
                        'weight': 'bold',
                        'size': 12})
  plt.ylabel('Valor',
              fontdict={'family': 'sans serif',
                        'color' : 'black',
                        'weight': 'bold',
                        'size': 12})
  plt.plot(dataframe['date'], dataframe['totalCases'], color = color)
  plt.show()


plot_graph(data_without_nan_values[data_without_nan_values['state'] == 'RR'],'red',"Avanço dos casos de covid em Roraima (2021-09-22 até 2022-07-25)")

# %%
plot_graph(data_without_nan_values[data_without_nan_values['state'] == 'AC'],'blue',"Avanço dos casos de covid no Acre (2021-09-27 até 2022-07-25)")

# %%
plot_graph(data_without_nan_values[data_without_nan_values['state'] == 'AP'],'purple',"Avanço dos casos de covid no Amapá (2021-09-24 até 2022-07-25)")

# %% [markdown]
# ## 5) Qual o aumento relativo de casos suspeitos de COVID-19 em 2022?

# %%
beginning_of_2022 = data_without_nan_values[data_without_nan_values['date']<'2022-01-01']['suspects'].sum()
now = data_without_nan_values['suspects'].sum()

print(f'Teve um aumento relativo de: {now*100/beginning_of_2022}%')
# Out:
# Teve um aumento relativo de: 298.0468324869345%

# %% [markdown]
# ## 6) Qual estado apresentou maior ocupação de leitos por COVID-19 desde o inicio da pandemia?

# %%
def occupation_per_state(field,title):
    country_group_sum = newDfTotal.groupby('estadoNotificacao')[field].sum()

    plt.figure(figsize =(11, 6))
    plt.bar(country_group_sum.index, country_group_sum.values, color = 'orange')
    plt.ylabel("Valores")
    plt.xlabel("# Estados")
    plt.title(title)
    plt.xticks(rotation='vertical')
    plt.yscale('log')
    plt.show()

occupation_per_state('totalOcupacaoCovid',"Ocupação hospitalar por Estado")

# %% [markdown]
# # Ao analisar o gráfico com a relação do total de ocupação hospitalar devido a COVID-19, podemos inferir que o estado que mais apresentou ocupação durante os 3 anos de pandemia foi o estado de São Paulo.

# %% [markdown]
# ## 7) Qual ano houve a maior incidência de COVID-19 na região sudeste do Brasil?

# %%
data = pd.read_csv('./cases-brazil-states.csv') 
data = data.dropna()
data['year'] = pd.DatetimeIndex(data['date']).year

# %%
# Regiões

norte = ['AM', 'PA', 'RR', 'AP', 'RO', 'AC' , 'TO']
nordeste =  ['PI', 'MA', 'PE', 'RN', 'PB', 'CE', 'BA', 'AL','SE']
centro_oeste =  ['MT', 'MS','GO']
sudeste =  ['SP', 'RJ', 'ES', 'MG']
sul =  ['RS', 'PR', 'SC']


def incidence_southeast(region):
  sum = 0

  for state in region:
    sum += data[data['state'] == state]['totalCases'].sum()
  
  return sum


def list_(regions):
  values = []
  for region in regions:
    values.append(incidence_southeast(region))

  return values  

values = list_([norte,nordeste,centro_oeste,sudeste,sul])
regions = ['Norte','Nordeste','Centro Oeste','Sudeste','Sul']

# %%
year_region = pd.DataFrame(list(zip(data['totalCases'], data['year'], regions)), columns = ['CasosTotais', 'Ano', 'Região'])
print(year_region)
# Out:
#    CasosTotais   Ano        Região
# 0       369475  2021         Norte
# 1     20834790  2021      Nordeste
# 2       369733  2021  Centro Oeste
# 3     20858394  2021       Sudeste
# 4       369916  2021           Sul

# %%
year_region['Ano']
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: Ano, dtype: int64

# %%
#Número total de casos de COVID por ano

data_groupby = data.groupby('year')['totalCases'].sum()
data_groupby
# Out:
# year
# 2021     4960492477
# 2022    12086896958
# Name: totalCases, dtype: int64

# %% [markdown]
# ## 8) Qual estado apresentou maior número de casos por 100 mil habitantes no ano de 2021?

# %%
def get_by_year(df): 
  df["Date"] = pd.to_datetime(df["date"])
  df['Year'] = df['Date'].dt.year  
  df = df.drop('date', axis=1)
  return df[df['Year'] == 2021] 


cols = ['date', 'state',  
       'totalCases_per_100k_inhabitants']  

data = pd.read_csv('./cases-brazil-states.csv',usecols = cols, sep=',') 
df = data.dropna()      
cases = data.groupby('state')['totalCases_per_100k_inhabitants'].sum().sort_values()
only_21 = get_by_year(df)

# %%
plt.figure(figsize =(11, 6))
plt.bar(cases.index, cases.values, color = 'orange')
plt.ylabel("Valores")
plt.xlabel("# Estados")
plt.title("Casos por 100 mil habitantes em 2021")
plt.xticks(rotation='vertical')
plt.yscale('log')
plt.show()

# %% [markdown]
# ## 9) Qual estado apresentou maior número de mortes por 100 mil habitantes no ano de 2021?

# %%
def get_by_year(df): 
  df["Date"] = pd.to_datetime(df["date"])
  df['Year'] = df['Date'].dt.year  
  df = df.drop('date', axis=1)
  return df[df['Year'] == 2021] 


cols = ['date', 'state',  
       'deaths_per_100k_inhabitants']  

data = pd.read_csv('./cases-brazil-states.csv',usecols = cols, sep=',') 
df = data.dropna()      
deaths = data.groupby('state')['deaths_per_100k_inhabitants'].sum().sort_values()
only_21 = get_by_year(df)


plt.figure(figsize =(11, 6))
plt.bar(deaths.index, deaths.values, color = 'orange')
plt.ylabel("Mortes")
plt.xlabel("# Estados")
plt.title("Mortes por Estados")
plt.xticks(rotation='vertical')
plt.yscale('log')
plt.show()

# %% [markdown]
# #Percebe-se que o estado em que foi relatado um maior número de mortes por COVID-19 no ano de 2021 foi o Rio de Janeiro

# %% [markdown]
# ## 10) Qual estado apresentou maior número de recuperados nos três anos de pandemia?

# %% [markdown]
# ### Para identificar qual estado possuiu maior número de pacientes recuperados do COVID podemos realizar um groupby relacionando os estados e a coluna "recovered". Essa por sua vez, é responsável por guardar o número de casos recuperados, que é incrementado diáriamente.

# %% [markdown]
# ### Como podemos observar abaixo, o estado de São Paulo possui mais de 4,8 milhões de recuperados de um total de aproximadamente 27,4 milhões em todo o país. Isso ocorre principalmente pelo tamanho da população de SP, bem como, a quantidade de contaminados.

# %%
cols_10 = ['suspects','date','state','totalCases','vaccinated', 'vaccinated_per_100_inhabitants', 'vaccinated_second',
       'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
       'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
       'vaccinated_third_per_100_inhabitants','totalCases_per_100k_inhabitants','deaths','recovered']
data_10 = pd.read_csv('./cases-brazil-states.csv', usecols = cols, sep=',') 
data_recovered = data_10.groupby('state')['recovered'].max().sort_values(ascending=False).head()
display(data_recovered)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-98260bb7b5b9> in <module>()
#       4        'vaccinated_third_per_100_inhabitants','totalCases_per_100k_inhabitants','deaths','recovered']
#       5 data_10 = pd.read_csv('./cases-brazil-states.csv', usecols = cols, sep=',')
# ----> 6 data_recovered = data_10.groupby('state')['recovered'].max().sort_values(ascending=False).head()
#       7 display(data_recovered)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: recovered'

# %% [markdown]
# ### Quando observamos o total de casos por 100.000 habitantes percebemos que São Paulo não está entre os estados mais preocupantes.

# %%
data_100k = data.groupby('state')['totalCases_per_100k_inhabitants'].max().sort_values(ascending=False).head()
display(data_100k)

# %% [markdown]
# ### Esse valor representa cerca de 5.65 % do total de recuperados.

# %%
(27381416/4850000)

# %%
plt.figure(figsize=(10,10))
plt.title("Número total de casos de Covid por ano")
data_recovered.plot(kind='bar', x='state', y='recovered', color='purple', label = 'recovered')

# %% [markdown]
# ## 11) Qual estado em teria maior simpatia por uma nova dose de vacina?

# %% [markdown]
# ## 12) Há alguma relação entre estados e quantidade de doses aplicadas?

# %% [markdown]
# Para analisar se há alguma relação entre estados e quantidade de doses aplicadas, utilizamos o mapa de calor de correlações.
# Juntamente com a tabela apresentada, podemos perceber que a correlação entre os estados e a quantidade de doses aplicadas é de 0.382931.

# %%
data = pd.read_csv('./cases-brazil-states.csv') 
data = data.dropna()

# %%
correlation = data.corr()
correlation
# Out:
#                                        epi_week  newDeaths    deaths  \
# epi_week                               1.000000  -0.045049 -0.004645
# newDeaths                             -0.045049   1.000000  0.716207
# deaths                                -0.004645   0.716207  1.000000
# newCases                               0.089933   0.744855  0.594109
# totalCases                             0.039462   0.689381  0.987722
# deathsMS                              -0.004638   0.716173  1.000000
# totalCasesMS                           0.039467   0.689256  0.987713
# deaths_per_100k_inhabitants            0.130540   0.056532  0.092174
# totalCases_per_100k_inhabitants        0.385403  -0.099652 -0.113154
# deaths_by_totalCases                  -0.369598   0.169240  0.207788
# recovered                              0.026256   0.687038  0.991219
# suspects                              -0.003072   0.641052  0.883580
# tests                                  0.000391   0.707971  0.994426
# tests_per_100k_inhabitants             0.105940  -0.010317 -0.013513
# vaccinated                             0.005331   0.707572  0.998215
# vaccinated_per_100_inhabitants         0.595261   0.062035  0.143508
# vaccinated_second                      0.045118   0.667090  0.984804
# vaccinated_second_per_100_inhabitants  0.720719   0.023802  0.120014
# vaccinated_single                     -0.007438   0.715493  0.998166
# vaccinated_single_per_100_inhabitants  0.049535   0.001017  0.003610
# vaccinated_third                       0.193596   0.471926  0.815747
# vaccinated_third_per_100_inhabitants   0.809956   0.011547  0.107904
#
#                                        newCases  totalCases  deathsMS  \
# epi_week                               0.089933    0.039462 -0.004638
# newDeaths                              0.744855    0.689381  0.716173
# deaths                                 0.594109    0.987722  1.000000
# newCases                               1.000000    0.605179  0.594084
# totalCases                             0.605179    1.000000  0.987725
# deathsMS                               0.594084    0.987725  1.000000
# totalCasesMS                           0.605006    1.000000  0.987716
# deaths_per_100k_inhabitants            0.061157    0.081590  0.092178
# totalCases_per_100k_inhabitants       -0.024136   -0.061737 -0.113151
# deaths_by_totalCases                   0.062531    0.123951  0.207788
# recovered                              0.589147    0.998675  0.991222
# suspects                               0.557115    0.891156  0.883579
# tests                                  0.593889    0.985972  0.994426
# tests_per_100k_inhabitants             0.009449    0.005957 -0.013510
# vaccinated                             0.598506    0.991380  0.998216
# vaccinated_per_100_inhabitants         0.099672    0.160979  0.143517
# vaccinated_second                      0.613271    0.989431  0.984808
# vaccinated_second_per_100_inhabitants  0.114485    0.145232  0.120023
# vaccinated_single                      0.595147    0.988179  0.998165
# vaccinated_single_per_100_inhabitants  0.009020    0.011599  0.003607
# vaccinated_third                       0.537952    0.874496  0.815764
# vaccinated_third_per_100_inhabitants   0.093616    0.147176  0.107916
#
#                                        totalCasesMS  \
# epi_week                                   0.039467
# newDeaths                                  0.689256
# deaths                                     0.987713
# newCases                                   0.605006
# totalCases                                 1.000000
# deathsMS                                   0.987716
# totalCasesMS                               1.000000
# deaths_per_100k_inhabitants                0.081598
# totalCases_per_100k_inhabitants           -0.061729
# deaths_by_totalCases                       0.123950
# recovered                                  0.998677
# suspects                                   0.891145
# tests                                      0.985964
# tests_per_100k_inhabitants                 0.005962
# vaccinated                                 0.991372
# vaccinated_per_100_inhabitants             0.161004
# vaccinated_second                          0.989428
# vaccinated_second_per_100_inhabitants      0.145251
# vaccinated_single                          0.988170
# vaccinated_single_per_100_inhabitants      0.011589
# vaccinated_third                           0.874534
# vaccinated_third_per_100_inhabitants       0.147209
#
#                                        deaths_per_100k_inhabitants  \
# epi_week                                                  0.130540
# newDeaths                                                 0.056532
# deaths                                                    0.092174
# newCases                                                  0.061157
# totalCases                                                0.081590
# deathsMS                                                  0.092178
# totalCasesMS                                              0.081598
# deaths_per_100k_inhabitants                               1.000000
# totalCases_per_100k_inhabitants                           0.625250
# deaths_by_totalCases                                      0.095207
# recovered                                                 0.079609
# suspects                                                  0.025200
# tests                                                     0.075306
# tests_per_100k_inhabitants                                0.396245
# vaccinated                                                0.055379
# vaccinated_per_100_inhabitants                            0.229397
# vaccinated_second                                         0.064794
# vaccinated_second_per_100_inhabitants                     0.225042
# vaccinated_single                                         0.074652
# vaccinated_single_per_100_inhabitants                     0.357537
# vaccinated_third                                          0.095030
# vaccinated_third_per_100_inhabitants                      0.225587
#
#                                        totalCases_per_100k_inhabitants  \
# epi_week                                                      0.385403
# newDeaths                                                    -0.099652
# deaths                                                       -0.113154
# newCases                                                     -0.024136
# totalCases                                                   -0.061737
# deathsMS                                                     -0.113151
# totalCasesMS                                                 -0.061729
# deaths_per_100k_inhabitants                                   0.625250
# totalCases_per_100k_inhabitants                               1.000000
# deaths_by_totalCases                                         -0.665456
# recovered                                                    -0.068324
# suspects                                                     -0.068062
# tests                                                        -0.094152
# tests_per_100k_inhabitants                                    0.618963
# vaccinated                                                   -0.124661
# vaccinated_per_100_inhabitants                                0.183919
# vaccinated_second                                            -0.108795
# vaccinated_second_per_100_inhabitants                         0.234303
# vaccinated_single                                            -0.106434
# vaccinated_single_per_100_inhabitants                         0.275954
# vaccinated_third                                             -0.022883
# vaccinated_third_per_100_inhabitants                          0.334269
#
#                                        deaths_by_totalCases  ...     tests  \
# epi_week                                          -0.369598  ...  0.000391
# newDeaths                                          0.169240  ...  0.707971
# deaths                                             0.207788  ...  0.994426
# newCases                                           0.062531  ...  0.593889
# totalCases                                         0.123951  ...  0.985972
# deathsMS                                           0.207788  ...  0.994426
# totalCasesMS                                       0.123950  ...  0.985964
# deaths_per_100k_inhabitants                        0.095207  ...  0.075306
# totalCases_per_100k_inhabitants                   -0.665456  ... -0.094152
# deaths_by_totalCases                               1.000000  ...  0.163132
# recovered                                          0.131603  ...  0.989288
# suspects                                           0.071366  ...  0.881717
# tests                                              0.163132  ...  1.000000
# tests_per_100k_inhabitants                        -0.406409  ...  0.046501
# vaccinated                                         0.186206  ...  0.995374
# vaccinated_per_100_inhabitants                    -0.066662  ...  0.159944
# vaccinated_second                                  0.170270  ...  0.985964
# vaccinated_second_per_100_inhabitants             -0.131533  ...  0.137218
# vaccinated_single                                  0.180661  ...  0.995458
# vaccinated_single_per_100_inhabitants             -0.060830  ...  0.014490
# vaccinated_third                                   0.073402  ...  0.822795
# vaccinated_third_per_100_inhabitants              -0.246575  ...  0.121957
#
#                                        tests_per_100k_inhabitants  vaccinated  \
# epi_week                                                 0.105940    0.005331
# newDeaths                                               -0.010317    0.707572
# deaths                                                  -0.013513    0.998215
# newCases                                                 0.009449    0.598506
# totalCases                                               0.005957    0.991380
# deathsMS                                                -0.013510    0.998216
# totalCasesMS                                             0.005962    0.991372
# deaths_per_100k_inhabitants                              0.396245    0.055379
# totalCases_per_100k_inhabitants                          0.618963   -0.124661
# deaths_by_totalCases                                    -0.406409    0.186206
# recovered                                                0.003449    0.994167
# suspects                                                -0.010482    0.889881
# tests                                                    0.046501    0.995374
# tests_per_100k_inhabitants                               1.000000   -0.020417
# vaccinated                                              -0.020417    1.000000
# vaccinated_per_100_inhabitants                           0.053328    0.146939
# vaccinated_second                                       -0.010671    0.990763
# vaccinated_second_per_100_inhabitants                    0.079541    0.126723
# vaccinated_single                                       -0.000216    0.997879
# vaccinated_single_per_100_inhabitants                    0.301301   -0.004668
# vaccinated_third                                         0.024011    0.830885
# vaccinated_third_per_100_inhabitants                     0.141441    0.113714
#
#                                        vaccinated_per_100_inhabitants  \
# epi_week                                                     0.595261
# newDeaths                                                    0.062035
# deaths                                                       0.143508
# newCases                                                     0.099672
# totalCases                                                   0.160979
# deathsMS                                                     0.143517
# totalCasesMS                                                 0.161004
# deaths_per_100k_inhabitants                                  0.229397
# totalCases_per_100k_inhabitants                              0.183919
# deaths_by_totalCases                                        -0.066662
# recovered                                                    0.153343
# suspects                                                     0.115296
# tests                                                        0.159944
# tests_per_100k_inhabitants                                   0.053328
# vaccinated                                                   0.146939
# vaccinated_per_100_inhabitants                               1.000000
# vaccinated_second                                            0.178327
# vaccinated_second_per_100_inhabitants                        0.932307
# vaccinated_single                                            0.141006
# vaccinated_single_per_100_inhabitants                        0.149120
# vaccinated_third                                             0.261462
# vaccinated_third_per_100_inhabitants                         0.821831
#
#                                        vaccinated_second  \
# epi_week                                        0.045118
# newDeaths                                       0.667090
# deaths                                          0.984804
# newCases                                        0.613271
# totalCases                                      0.989431
# deathsMS                                        0.984808
# totalCasesMS                                    0.989428
# deaths_per_100k_inhabitants                     0.064794
# totalCases_per_100k_inhabitants                -0.108795
# deaths_by_totalCases                            0.170270
# recovered                                       0.988863
# suspects                                        0.876778
# tests                                           0.985964
# tests_per_100k_inhabitants                     -0.010671
# vaccinated                                      0.990763
# vaccinated_per_100_inhabitants                  0.178327
# vaccinated_second                               1.000000
# vaccinated_second_per_100_inhabitants           0.170511
# vaccinated_single                               0.983659
# vaccinated_single_per_100_inhabitants          -0.000911
# vaccinated_third                                0.882940
# vaccinated_third_per_100_inhabitants            0.154891
#
#                                        vaccinated_second_per_100_inhabitants  \
# epi_week                                                            0.720719
# newDeaths                                                           0.023802
# deaths                                                              0.120014
# newCases                                                            0.114485
# totalCases                                                          0.145232
# deathsMS                                                            0.120023
# totalCasesMS                                                        0.145251
# deaths_per_100k_inhabitants                                         0.225042
# totalCases_per_100k_inhabitants                                     0.234303
# deaths_by_totalCases                                               -0.131533
# recovered                                                           0.135970
# suspects                                                            0.099929
# tests                                                               0.137218
# tests_per_100k_inhabitants                                          0.079541
# vaccinated                                                          0.126723
# vaccinated_per_100_inhabitants                                      0.932307
# vaccinated_second                                                   0.170511
# vaccinated_second_per_100_inhabitants                               1.000000
# vaccinated_single                                                   0.117799
# vaccinated_single_per_100_inhabitants                               0.151034
# vaccinated_third                                                    0.268984
# vaccinated_third_per_100_inhabitants                                0.859123
#
#                                        vaccinated_single  \
# epi_week                                       -0.007438
# newDeaths                                       0.715493
# deaths                                          0.998166
# newCases                                        0.595147
# totalCases                                      0.988179
# deathsMS                                        0.998165
# totalCasesMS                                    0.988170
# deaths_per_100k_inhabitants                     0.074652
# totalCases_per_100k_inhabitants                -0.106434
# deaths_by_totalCases                            0.180661
# recovered                                       0.991877
# suspects                                        0.889581
# tests                                           0.995458
# tests_per_100k_inhabitants                     -0.000216
# vaccinated                                      0.997879
# vaccinated_per_100_inhabitants                  0.141006
# vaccinated_second                               0.983659
# vaccinated_second_per_100_inhabitants           0.117799
# vaccinated_single                               1.000000
# vaccinated_single_per_100_inhabitants           0.040716
# vaccinated_third                                0.811599
# vaccinated_third_per_100_inhabitants            0.106022
#
#                                        vaccinated_single_per_100_inhabitants  \
# epi_week                                                            0.049535
# newDeaths                                                           0.001017
# deaths                                                              0.003610
# newCases                                                            0.009020
# totalCases                                                          0.011599
# deathsMS                                                            0.003607
# totalCasesMS                                                        0.011589
# deaths_per_100k_inhabitants                                         0.357537
# totalCases_per_100k_inhabitants                                     0.275954
# deaths_by_totalCases                                               -0.060830
# recovered                                                           0.011787
# suspects                                                           -0.008245
# tests                                                               0.014490
# tests_per_100k_inhabitants                                          0.301301
# vaccinated                                                         -0.004668
# vaccinated_per_100_inhabitants                                      0.149120
# vaccinated_second                                                  -0.000911
# vaccinated_second_per_100_inhabitants                               0.151034
# vaccinated_single                                                   0.040716
# vaccinated_single_per_100_inhabitants                               1.000000
# vaccinated_third                                                    0.015178
# vaccinated_third_per_100_inhabitants                                0.180013
#
#                                        vaccinated_third  \
# epi_week                                       0.193596
# newDeaths                                      0.471926
# deaths                                         0.815747
# newCases                                       0.537952
# totalCases                                     0.874496
# deathsMS                                       0.815764
# totalCasesMS                                   0.874534
# deaths_per_100k_inhabitants                    0.095030
# totalCases_per_100k_inhabitants               -0.022883
# deaths_by_totalCases                           0.073402
# recovered                                      0.857092
# suspects                                       0.721583
# tests                                          0.822795
# tests_per_100k_inhabitants                     0.024011
# vaccinated                                     0.830885
# vaccinated_per_100_inhabitants                 0.261462
# vaccinated_second                              0.882940
# vaccinated_second_per_100_inhabitants          0.268984
# vaccinated_single                              0.811599
# vaccinated_single_per_100_inhabitants          0.015178
# vaccinated_third                               1.000000
# vaccinated_third_per_100_inhabitants           0.320616
#
#                                        vaccinated_third_per_100_inhabitants
# epi_week                                                           0.809956
# newDeaths                                                          0.011547
# deaths                                                             0.107904
# newCases                                                           0.093616
# totalCases                                                         0.147176
# deathsMS                                                           0.107916
# totalCasesMS                                                       0.147209
# deaths_per_100k_inhabitants                                        0.225587
# totalCases_per_100k_inhabitants                                    0.334269
# deaths_by_totalCases                                              -0.246575
# recovered                                                          0.132892
# suspects                                                           0.094279
# tests                                                              0.121957
# tests_per_100k_inhabitants                                         0.141441
# vaccinated                                                         0.113714
# vaccinated_per_100_inhabitants                                     0.821831
# vaccinated_second                                                  0.154891
# vaccinated_second_per_100_inhabitants                              0.859123
# vaccinated_single                                                  0.106022
# vaccinated_single_per_100_inhabitants                              0.180013
# vaccinated_third                                                   0.320616
# vaccinated_third_per_100_inhabitants                               1.000000
#
# [22 rows x 22 columns]

# %%
sns.heatmap(data.corr())

# %% [markdown]
# ## 13) Houve redução no número de casos de COVID-19 após 1 ano da aplicação da primeira dose da vacina contra COVID-19?

# %% [markdown]
# ### Através do código abaixo podemos cobstatar que as primeiras doses registradas tratam-se do dia 17/01/2021.

# %%
cols_13 = ['vaccinated','date','state','totalCases_per_100k_inhabitants']
data_13 = pd.read_csv('./cases-brazil-states.csv', usecols = cols_13, sep=',')
first_vaccination = data_13[(data_13['state'] == 'TOTAL')].dropna().sort_values(by=['date']).head(1)
first_vaccination

# %% [markdown]
# ### Após 1 ano, os seguintes dados foram coletados:

# %%
first_vaccination_1_year = data_13[(data_13['state'] == 'TOTAL') & (data_13['date'] == '2022-01-17')].dropna().sort_values(by=['date']).head(1)
first_vaccination_1_year

# %% [markdown]
# ### Para responder essa pergunta, podemos tomar a porcentagem de contaminação comparada a quantidade de vacinados da seguinte maneira.

# %%
def percent(total_cases, vaccinated):
  return (total_cases/vaccinated)*100

# %%
case_1 = percent(112,3980)
print("Inicio: {:.2f} %".format(case_1))

# %%
case_2 = percent(162370844,10824)
print("Fim: {:.2f} %".format(case_2))

# %% [markdown]
# ### Logo, percebemos que comparando o total de casos com o total de vacinados, ocorreu uma redução drástica do número de contaminados.

# %% [markdown]
# ## 14) Houve redução no número de testes de COVID-19 após 1 ano da aplicação da primeira dose da vacina contra COVID-19?

# %% [markdown]
# ### De maneira semelhante à questão anterior, é possível retirar as seguintes conclusões.

# %%
cols_14 = ['vaccinated','date','state','totalCases_per_100k_inhabitants','tests_per_100k_inhabitants']
data_14 = pd.read_csv('./cases-brazil-states.csv', usecols = cols_13, sep=',')
first_vaccination = data_13[(data_13['state'] == 'TOTAL')].dropna().sort_values(by=['date']).head(1)
first_vaccination
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-fbb982c1078e> in <module>()
#       1 cols_14 = ['vaccinated','date','state','totalCases_per_100k_inhabitants','tests_per_100k_inhabitants']
# ----> 2 data_14 = pd.read_csv('./cases-brazil-states.csv', usecols = cols_13, sep=',')
#       3 first_vaccination = data_13[(data_13['state'] == 'TOTAL')].dropna().sort_values(by=['date']).head(1)
#       4 first_vaccination
#
# NameError: name 'cols_13' is not defined

# %%
first_vaccination_1_year = data_13[(data_13['state'] == 'TOTAL') & (data_13['date'] == '2022-01-17')].dropna().sort_values(by=['date']).head(1)
first_vaccination_1_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-275c983b2e70> in <module>()
# ----> 1 first_vaccination_1_year = data_13[(data_13['state'] == 'TOTAL') & (data_13['date'] == '2022-01-17')].dropna().sort_values(by=['date']).head(1)
#       2 first_vaccination_1_year
#
# NameError: name 'data_13' is not defined

# %% [markdown]
# ### Dessa forma, é perceptivel que houve um aumento percentual na quantidade de testes realizados.

# %% [markdown]
# ## 15) Qual estado realizou a maior testagem nos três anos?

# %% [markdown]
# ### Baseando-se nos dados disponibilizados pelo dataset, podemos observar uma coluna que trata de quantidade de teste realizados por 100.000 habitantes. Dessa forma, agrupando esses dados por estado, é perceptível que Roraima está presente no primeiro lugar.

# %%
cols_15 = ['state','tests_per_100k_inhabitants']
data_15 = pd.read_csv('./cases-brazil-states.csv', usecols = cols_15, sep=',')
data_15.groupby('state').max().sort_values(by=['tests_per_100k_inhabitants'], axis=0, ascending=False).head()
# Out:
#        tests_per_100k_inhabitants
# state
# RS                    68117.36134
# RR                    66655.66123
# RO                    62512.00608
# ES                    59629.30337
# TO                    57473.10960

# %% [markdown]
# ## 16) Qual estado aplicou mais vacinas até o momento?

# %%
data = pd.read_csv('./cases-brazil-states.csv') 
data = data.dropna()    
data = data[data.state != 'TOTAL']

# %%
#Agrupando por estado e número de vacinados
state_vaccinated = data.groupby('state')['vaccinated'].max()

# %%
#state_vaccinated = state_vaccinated[state_vaccinated != 'TOTAL']
state_vaccinated
# Out:
# state
# AC      667597.0
# AL     2596051.0
# AM     3215752.0
# AP      586245.0
# BA    11643243.0
# CE     8167779.0
# DF     2530653.0
# ES     3410209.0
# GO     5818389.0
# MA     5646024.0
# MG    17989682.0
# MS     2246196.0
# MT     2797353.0
# PA     6869194.0
# PB     3547278.0
# PE     8366672.0
# PI     3163444.0
# PR    10054087.0
# RJ    14385308.0
# RN     2933984.0
# RO     1302438.0
# RR      436859.0
# RS     9722752.0
# SC     6237943.0
# SE     1972991.0
# SP    42396507.0
# TO     1157010.0
# Name: vaccinated, dtype: float64

# %% [markdown]
# Analisando os dados apresentados, é possível observar que o estado que aplicou mais vacinas até o momento foi São Paulo, com um total de 42396507 vacinas aplicadas.

# %%
print('Estado:', state_vaccinated.idxmax())
print('Número total de vacinas: ', state_vaccinated.max())
# Out:
# Estado: SP
# Número total de vacinas:  42396507.0

# %% [markdown]
# ## 17)   Qual estado apresentou maior sobrecarga do sistema por suspeita de COVID-19 desde o inicio da pandemia?

# %%
def occupation_per_state(field,title):
    country_group_sum = newDfTotal.groupby('estadoNotificacao')[field].sum()

    plt.figure(figsize =(11, 6))
    plt.bar(country_group_sum.index, country_group_sum.values, color = 'orange')
    plt.ylabel("Valores")
    plt.xlabel("# Estados")
    plt.title(title)
    plt.xticks(rotation='vertical')
    plt.yscale('log')
    plt.show()

occupation_per_state('totalOcupacaoHospitalar',"Ocupação hospitalar por Estado")

# %% [markdown]
# # Ao analisar o gráfico com a relação do total de ocupação hospitalar devido independente de doença, no periodo da pandemia, podemos inferir que o estado que mais apresentou ocupação durante os 3 anos de pandemia foi o estado de São Paulo.

# %% [markdown]
# ## 18) Utilize o KNN como técnica de aprendizado de máquina supervisionado para prever o total de casos de COVID-19 por 100k de habitantes

# %%
from sklearn import metrics

# %%
data['totalCases_per_100k_inhabitants_test'] = data['totalCases_per_100k_inhabitants'].apply(lambda x: 1 if x > data['totalCases_per_100k_inhabitants'].mean() else 0)
data['vaccinated_per_100_inhabitants_test'] = data['vaccinated_per_100_inhabitants'].apply(lambda x: 1 if x > data['vaccinated_per_100_inhabitants'].mean() else 0)

# %%
sns.pairplot(data)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


def classifier(X_train,X_test,Y_train,Y_test):
    #Aplicando KNN
    print(" KNN ")
    ini = time.time() #Inicio do calculo do tempo

    knn=KNeighborsClassifier()
    knn.fit(X_train,Y_train)

    end = time.time()
    knn_time = end - ini # Fim do calculo do tempo

    knn_Y_predicted = knn.predict(X_test)
    knn_accuracy = np.sum(knn_Y_predicted == Y_test) / len(Y_test)

    print(classification_report(Y_test,knn.predict(X_test)))
    print(confusion_matrix(Y_test, knn.predict(X_test)))

    cm = metrics.confusion_matrix(Y_test, knn_Y_predicted, labels=knn.classes_)
    disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=knn.classes_)
    disp.plot()
    plt.show()
    

Y = data['totalCases_per_100k_inhabitants_test']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(data['vaccinated_per_100_inhabitants_test'].values.reshape(-1,1),Y.values.reshape(-1,1),test_size=0.2, random_state=0)
classifier(X_train,X_test,Y_train,Y_test)
# Out:
#  KNN
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      2622
#            1       0.89      0.74      0.81      2225
#
#     accuracy                           0.84      4847
#    macro avg       0.85      0.83      0.83      4847
# weighted avg       0.84      0.84      0.84      4847
#
# [[2412  210]
#  [ 573 1652]]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
